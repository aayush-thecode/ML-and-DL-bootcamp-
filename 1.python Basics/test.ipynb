# %% [markdown]
# ### Python Example

# %% [markdown]
# ## basic syntax rules In python
# ## case sensitivity

# %% [markdown]
# Intendention
#
# intendention in Python is used to define the structure and hierarchy of the code. unlike many other languages that use braces{} to delimit the blocks of code, Python uses indentation to determine the grouping of statements. This means that all the statements  within the block must be indented at the sane level.

# %% [markdown]
# ##multiple statement on a single line

# %%
## Line Continuation

total = 1+2+3+4+\
4+6+7

print(total)

# %%
## understandinf semantics in python 
#variable assignments

age = 32 ## age is an integer
name = "Aayush" ## name is a string

# %%
## type inference

type(age)

# %%
##tyoe inference
variable = 10
print(type(variable))
variable = "aayush"
print(type(variable))

# %%
## code example of indentation
if True:
    print("correct Intendation")
    if False:
        print("this is not print")
    print("this will print")
print("Outside the print block")
# Out:
# Error: No connection selected.

# %%
#declaring and assigning variables

age = 21
height = 5.7
name = 'Aayush'

print('Age:', age)
print('Height:', height)
print('Name:', name)
# Out:
# Age: 21
# Height: 5.7
# Name: Aayush

# %%
## understanding variable types 
## python is dynamically typed, type of a variable is determined at runtime

age = 25 # int
height = 5.7 #float
name = 'Aayush' #string

# %%
## dynamic typing
## python allows the type of a variable to change as the program execute

# %% [markdown]
# Advanced data types
# list
# tuples
# sets and
# dictionaries
#
# type conversion
# practical examples

# %%
## common errors

result = "hello " + str(5)
print(result)
# Out:
# hello 5
