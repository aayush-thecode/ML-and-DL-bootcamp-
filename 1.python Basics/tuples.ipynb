# %%
## creating a tuple

empty_tuple = ()
print(empty_tuple)
print(type(empty_tuple))
# Out:
# ()
# <class 'tuple'>

# %%
lst =list()
print(type(lst))
tpl = tuple()
print(type(tpl))
# Out:
# <class 'list'>
# <class 'tuple'>

# %%
num = tuple([1,2,3,4,5,6,7])
num
# Out:
# (1, 2, 3, 4, 5, 6, 7)

# %%
list((1,2,3,4,5,6,7))
# Out:
# [1, 2, 3, 4, 5, 6, 7]
